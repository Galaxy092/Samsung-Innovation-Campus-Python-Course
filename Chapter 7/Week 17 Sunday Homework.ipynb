# %% [markdown]
# ## Exercise 36 - Spotify Data Analysis

# %%
# Step 1
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
song = pd.read_csv('spotify_global_2019_most_streamed_tracks_audio_features.csv')

# %%
song.head()
# Out:
#   Country  Rank                Track_id     Streams        Track Name  \
# 0  global   1.0  25sgk305KZfyuqVBQIahim  1166185736  Sweet but Psycho
# 1  global   2.0  2Fxmhks0bxGSBdJ92vM42m  1052358787           bad guy
# 2  global   3.0  6ocbgoVGwYJhOv1GgI9NsF   789094044           7 rings
# 3  global   4.0  1rgnBhdG2JDFTbYkYRZAku   764208309      Dance Monkey
# 4  global   5.0  6v3KW9xbzN5yKLt9YKDYA2   763064359          Señorita
#
#           Artist                                                URL  \
# 0        Ava Max  https://open.spotify.com/track/25sgk305KZfyuqV...
# 1  Billie Eilish  https://open.spotify.com/track/2Fxmhks0bxGSBdJ...
# 2  Ariana Grande  https://open.spotify.com/track/6ocbgoVGwYJhOv1...
# 3    Tones and I  https://open.spotify.com/track/1rgnBhdG2JDFTbY...
# 4   Shawn Mendes  https://open.spotify.com/track/6v3KW9xbzN5yKLt...
#
#    acousticness  danceability  energy  ...  valence    tempo  time_signature  \
# ...

# %%
# A Method to check the total number of DataFrames and data types of the imported DataFrame
song.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1717 entries, 0 to 1716
# Data columns (total 24 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Country            1717 non-null   object
#  1   Rank               1717 non-null   float64
#  2   Track_id           1717 non-null   object
#  3   Streams            1717 non-null   int64
#  4   Track Name         1717 non-null   object
#  5   Artist             1717 non-null   object
#  6   URL                1717 non-null   object
#  7   acousticness       1717 non-null   float64
#  8   danceability       1717 non-null   float64
#  9   energy             1717 non-null   float64
#  10  instrumentalness   1717 non-null   float64
#  11  liveness           1717 non-null   float64
#  12  loudness           1717 non-null   float64
#  13  speechiness        1717 non-null   float64
#  14  valence            1717 non-null   float64
# ...

# %%
# A Method to check data distribution
song.describe()
# Out:
#               Rank       Streams  acousticness  danceability       energy  \
# count  1717.000000  1.717000e+03   1717.000000   1717.000000  1717.000000
# mean    859.000000  5.166175e+07      0.257652      0.675438     0.624354
# std     495.799523  1.047532e+08      0.256975      0.154163     0.172298
# min       1.000000  5.242300e+05      0.000037      0.151000     0.013700
# 25%     430.000000  1.763026e+06      0.051900      0.584000     0.525000
# 50%     859.000000  9.623926e+06      0.171000      0.694000     0.646000
# 75%    1288.000000  4.829352e+07      0.385000      0.787000     0.747000
# max    1717.000000  1.166186e+09      0.979000      0.974000     0.978000
#
#        instrumentalness     liveness     loudness  speechiness      valence  \
# count       1717.000000  1717.000000  1717.000000  1717.000000  1717.000000
# mean           0.014577     0.174317    -6.477624     0.129967     0.487719
# ...

# %%
# Step 2 select only necessary columns and recreates the DataFrame
df = song[["Rank", "Artist", "Track Name", "Artist_popularity", "Streams", "tempo", "danceability", "energy"]]
df.head()
# Out:
#    Rank         Artist        Track Name  Artist_popularity     Streams  \
# 0   1.0        Ava Max  Sweet but Psycho                 87  1166185736
# 1   2.0  Billie Eilish           bad guy                 98  1052358787
# 2   3.0  Ariana Grande           7 rings                 97   789094044
# 3   4.0    Tones and I      Dance Monkey                 92   764208309
# 4   5.0   Shawn Mendes          Señorita                 94   763064359
#
#      tempo  danceability  energy
# 0  133.002         0.719   0.704
# 1  135.128         0.701   0.425
# 2  140.048         0.778   0.317
# 3   98.078         0.825   0.593
# 4  116.967         0.759   0.548

# %%
# Step 3 filter only artist that have popularity of 95 or higher
pop_song = df[df["Artist_popularity"] > 90]
pop_song.head()
# Out:
#    Rank         Artist    Track Name  Artist_popularity     Streams    tempo  \
# 1   2.0  Billie Eilish       bad guy                 98  1052358787  135.128
# 2   3.0  Ariana Grande       7 rings                 97   789094044  140.048
# 3   4.0    Tones and I  Dance Monkey                 92   764208309   98.078
# 4   5.0   Shawn Mendes      Señorita                 94   763064359  116.967
# 5   6.0   Daddy Yankee     Con Calma                 95   715027898   93.989
#
#    danceability  energy
# 1         0.701   0.425
# 2         0.778   0.317
# 3         0.825   0.593
# 4         0.759   0.548
# 5         0.737   0.860

# %%
# Counts tht total number of non-duplicate unique data elements (values) and returns them as a series object.
rank = pop_song["Artist"].value_counts()

# %%
rank
# Out:
# Post Malone      45
# Juice WRLD       31
# Ariana Grande    28
# Billie Eilish    27
# Taylor Swift     27
#                  ..
# Nicki Minaj       1
# J. Cole           1
# Rihanna           1
# Bass Santana      1
# Bruno Mars        1
# Name: Artist, Length: 62, dtype: int64

# %%
type(rank)
# Out:
# pandas.core.series.Series

# %%
pop_song["Artist"].unique()
# Out:
# array(['Billie Eilish', 'Ariana Grande', 'Tones and I', 'Shawn Mendes',
#        'Daddy Yankee', 'Lewis Capaldi', 'Post Malone', 'Halsey',
#        'Sam Smith', 'Ed Sheeran', 'Anuel AA', 'Bad Bunny', 'J. Cole',
#        'Travis Scott', 'Juice WRLD', 'Maroon 5', 'Khalid', 'Sech',
#        'Drake', 'XXXTENTACION', 'Lauv', 'J Balvin',
#        'A Boogie Wit da Hoodie', 'Imagine Dragons', 'Queen', 'Ozuna',
#        'Nicky Jam', 'Maluma', 'Chris Brown', 'Lil Baby', 'DaBaby', 'BTS',
#        'Selena Gomez', 'Cardi B', 'Dua Lipa', 'Camila Cabello', 'Dalex',
#        'The Chainsmokers', 'Young Thug', 'Tyga', 'Taylor Swift',
#        'Justin Quiles', 'KAROL G', 'Myke Towers', 'Lil Uzi Vert',
#        'Harry Styles', 'The Weeknd', 'Kanye West', 'Michael Bublé',
#        'Justin Bieber', 'Roddy Ricch', 'Kendrick Lamar', 'Future',
#        'YoungBoy Never Broke Again', 'Coldplay', 'Eminem', 'Nicki Minaj',
#        'Trippie Redd', 'Gunna', 'Rihanna', 'Bass Santana', 'Bruno Mars'],
# ...

# %%
# Step 4
'BTS' in rank
# Out:
# True

# %%
# BTS 11 songs in total
bts = pop_song[pop_song["Artist"] == "BTS"]
bts.shape
# Out:
# (11, 8)

# %%
bts
# Out:
#         Rank Artist                                         Track Name  \
# 86      87.0    BTS                        Boy With Luv (feat. Halsey)
# 464    465.0    BTS                         Make It Right (feat. Lauv)
# 676    677.0    BTS                                        Mikrokosmos
# 678    679.0    BTS  Dream Glow (BTS World Original Soundtrack) - P...
# 681    682.0    BTS                                      Make It Right
# 710    711.0    BTS                                               HOME
# 725    726.0    BTS                                           Dionysus
# 778    779.0    BTS                                          Jamais Vu
# 883    884.0    BTS                                    Intro : Persona
# 1057  1058.0    BTS  A Brand New Day (BTS World Original Soundtrack...
# 1265  1266.0    BTS  All Night (BTS World Original Soundtrack) [Pt. 3]
#
#       Artist_popularity    Streams    tempo  danceability  energy
# ...

# %%
# Step 5
play_list = pop_song[pop_song["Artist"] == "Post Malone"]

Malone = play_list.reset_index(drop = True, inplace = False)

Malone
# Out:
#       Rank       Artist                                         Track Name  \
# 0     10.0  Post Malone                                               Wow.
# 1     14.0  Post Malone                        Goodbyes (Feat. Young Thug)
# 2     26.0  Post Malone                                            Circles
# 3     32.0  Post Malone                                         Better Now
# 4     34.0  Post Malone                         rockstar (feat. 21 Savage)
# 5    113.0  Post Malone      Sunflower - Spider-Man: Into the Spider-Verse
# 6    126.0  Post Malone                       Psycho (feat. Ty Dolla $ign)
# 7    174.0  Post Malone  Take What You Want (feat. Ozzy Osbourne & Trav...
# 8    192.0  Post Malone                                    Congratulations
# 9    228.0  Post Malone                                       Saint-Tropez
# 10   230.0  Post Malone                                       I Fall Apart
# ...

# %%
# Step 6 - Expressing the tempo by rank as a scatter plot graph
x = pop_song["energy"]
y = pop_song["Rank"]
plt.scatter(x, y, color = 'red', alpha = 0.5)

plt.show()

# %%
cor = pop_song.corr(method='pearson')
cor
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_12832\1185531361.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   cor = pop_song.corr(method='pearson')
#                        Rank  Artist_popularity   Streams     tempo  \
# Rank               1.000000          -0.125771 -0.667177  0.055495
# Artist_popularity -0.125771           1.000000  0.076414  0.033521
# Streams           -0.667177           0.076414  1.000000 -0.034935
# tempo              0.055495           0.033521 -0.034935  1.000000
# danceability      -0.014811          -0.084745  0.084925  0.040506
# energy             0.015078           0.019909 -0.061912  0.245615
#
#                    danceability    energy
# Rank                  -0.014811  0.015078
# Artist_popularity     -0.084745  0.019909
# Streams                0.084925 -0.061912
# ...

# %%
plt.matshow(cor)
plt.colorbar()

# %%
plt.figure(figsize = (8, 6))
sns.heatmap(cor, annot = True)
plt.show()

# %% [markdown]
# ## Unit 37 - Data Tidying

# %% [markdown]
# ## Exercise 37

# %%
# Step 1
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

student_data = pd.read_csv('student-mat.csv', sep=';')
student_data.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
student_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      395 non-null    object
#  1   sex         395 non-null    object
#  2   age         395 non-null    int64
#  3   address     395 non-null    object
#  4   famsize     395 non-null    object
#  5   Pstatus     395 non-null    object
#  6   Medu        395 non-null    int64
#  7   Fedu        395 non-null    int64
#  8   Mjob        395 non-null    object
#  9   Fjob        395 non-null    object
#  10  reason      395 non-null    object
#  11  guardian    395 non-null    object
#  12  traveltime  395 non-null    int64
#  13  studytime   395 non-null    int64
#  14  failures    395 non-null    int64
#  15  schoolsup   395 non-null    object
#  16  famsup      395 non-null    object
#  17  paid        395 non-null    object
#  18  activities  395 non-null    object
# ...

# %%
student_data.isnull().sum()
# Out:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %%
student_data.isnull().sum().sum()
# Out:
# 0

# %%
plt.hist(student_data['absences'])

plt.xlabel('absence')
plt.ylabel('count')

plt.grid(True)

# %%
plt.hist(student_data['age'])

plt.xlabel('age')
plt.ylabel('count')

plt.grid(True)

# %%
student_data.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean    16.696203    2.749367    2.521519    1.448101    2.035443    0.334177
# std      1.276043    1.094735    1.088201    0.697505    0.839240    0.743651
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    2.000000    1.000000    1.000000    0.000000
# 50%     17.000000    3.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean     3.944304    3.235443    3.108861    1.481013    2.291139    3.554430
# ...

# %%
student_data['studytime'].median()
# Out:
# 2.0

# %%
student_data['studytime'].mode()
# Out:
# 0    2
# Name: studytime, dtype: int64

# %%
student_data['studytime'].var()
# Out:
# 0.7043243590567373

# %%
student_data['studytime'].std()
# Out:
# 0.8392403464185556

# %%
plt.boxplot(student_data['G1'])
plt.grid(True)

# %%
plt.boxplot(student_data['absences'])
plt.grid(True)

# %%
plt.boxplot([student_data['G1'], student_data['G2'], student_data['G3'], student_data['Walc'], student_data['absences']])
plt.grid(True)

# %%
study_time_cv = student_data['studytime'].std()/ student_data['studytime'].mean()
print(study_time_cv)
# Out:
# 0.4123133542727978

# %%
absences_cv = student_data['absences'].std()/ student_data['absences'].mean()
print(absences_cv)
# Out:
# 1.4018726369879073

# %%
cv = student_data.std()/ student_data.mean()
cv
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_12832\1330258795.py:1: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   cv = student_data.std()/ student_data.mean()
# C:\Users\Acer\AppData\Local\Temp\ipykernel_12832\1330258795.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   cv = student_data.std()/ student_data.mean()
# age           0.076427
# Medu          0.398177
# Fedu          0.431565
# traveltime    0.481668
# studytime     0.412313
# failures      2.225319
# famrel        0.227330
# freetime      0.308725
# ...

# %%
student_data.cov(min_periods=None , ddof=1)
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_12832\3731043047.py:1: FutureWarning: The default value of numeric_only in DataFrame.cov is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   student_data.cov(min_periods=None , ddof=1)
#                  age      Medu      Fedu  traveltime  studytime  failures  \
# age         1.628285 -0.228619 -0.226949    0.062873  -0.004434  0.231221
# Medu       -0.228619  1.198445  0.742717   -0.131061   0.059667 -0.192681
# Fedu       -0.226949  0.742717  1.184180   -0.120073  -0.008379 -0.202641
# traveltime  0.062873 -0.131061 -0.120073    0.486513  -0.059070  0.047844
# studytime  -0.004434  0.059667 -0.008379   -0.059070   0.704324 -0.108321
# failures    0.231221 -0.192681 -0.202641    0.047844  -0.108321  0.553017
# famrel      0.061717 -0.003842 -0.001337   -0.010512   0.029898 -0.029564
# ...

# %%
np.cov(student_data['G1'], student_data['G3'])
# Out:
# array([[11.01705327, 12.18768232],
#        [12.18768232, 20.9896164 ]])

# %%
print(student_data['G1'].var())
print(student_data['G3'].var())
# Out:
# 11.017053267364904
# 20.989616397866733

# %%
student_data.corr()
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_12832\1809258949.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   student_data.corr()
#                  age      Medu      Fedu  traveltime  studytime  failures  \
# age         1.000000 -0.163658 -0.163438    0.070641  -0.004140  0.243665
# Medu       -0.163658  1.000000  0.623455   -0.171639   0.064944 -0.236680
# Fedu       -0.163438  0.623455  1.000000   -0.158194  -0.009175 -0.250408
# traveltime  0.070641 -0.171639 -0.158194    1.000000  -0.100909  0.092239
# studytime  -0.004140  0.064944 -0.009175   -0.100909   1.000000 -0.173563
# failures    0.243665 -0.236680 -0.250408    0.092239  -0.173563  1.000000
# famrel      0.053940 -0.003914 -0.001370   -0.016808   0.039731 -0.044337
# freetime    0.016434  0.030891 -0.012846   -0.017025  -0.143198  0.091987
# ...

# %%
plt.plot(student_data['G1'], student_data['G3'],'o')
plt.grid(True)

# %%
sns.pairplot(student_data[['Dalc','Walc', 'G1','G3']])
plt.grid(True)

# %% [markdown]
# ## Excersie 37 (University Ranking cleaning data)

# %%
import pandas as pd

# Read the CSV file into a DataFrame
df = pd.read_json("universities_ranking.json")

# Check for missing data
missing_data = df.isnull().sum()
print(missing_data)
# Out:
# world_rank              0
# institution             0
# country                 0
# national_rank           0
# quality_of_education    0
# alumni_employment       0
# quality_of_faculty      0
# publications            0
# influence               0
# citations               0
# broad_impact            0
# patents                 0
# score                   0
# year                    0
# dtype: int64

# %%
# Replace missing values with a specific value (e.g., 'Unknown')
df_filled = df.fillna('Unknown')

# Or delete rows with missing values
df_dropped = df.dropna()

# %% [markdown]
# ## Unit 38 - Time Series Data

# %%
import pandas as pd
import numpy as np
import datetime
import matplotlib.pyplot as plt
from datetime import date , datetime , time , timezone

df = pd.read_csv('capture-fisheries-vs-aquaculture.csv')
df.head()
# Out:
#         Entity Code  Year  Aquaculture production (metric tons)  \
# 0  Afghanistan  AFG  1969                                  60.0
# 1  Afghanistan  AFG  1970                                  60.0
# 2  Afghanistan  AFG  1971                                  60.0
# 3  Afghanistan  AFG  1972                                  60.0
# 4  Afghanistan  AFG  1973                                  60.0
#
#    Capture fisheries production (metric tons)
# 0                                       400.0
# 1                                       400.0
# 2                                       500.0
# 3                                       500.0
# 4                                       500.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12727 entries, 0 to 12726
# Data columns (total 5 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Entity                                      12727 non-null  object
#  1   Code                                        11901 non-null  object
#  2   Year                                        12727 non-null  int64
#  3   Aquaculture production (metric tons)        9710 non-null   float64
#  4   Capture fisheries production (metric tons)  12569 non-null  float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 497.3+ KB

# %%
df.drop(['Code'], axis =1 , inplace=True)
df.head()
# Out:
#         Entity  Year  Aquaculture production (metric tons)  \
# 0  Afghanistan  1969                                  60.0
# 1  Afghanistan  1970                                  60.0
# 2  Afghanistan  1971                                  60.0
# 3  Afghanistan  1972                                  60.0
# 4  Afghanistan  1973                                  60.0
#
#    Capture fisheries production (metric tons)
# 0                                       400.0
# 1                                       400.0
# 2                                       500.0
# 3                                       500.0
# 4                                       500.0

# %%
df.isnull().sum()
# Out:
# Entity                                           0
# Year                                             0
# Aquaculture production (metric tons)          3017
# Capture fisheries production (metric tons)     158
# dtype: int64

# %%
change_value = 0
df.fillna(change_value, inplace=True)
df.isnull().sum()
# Out:
# Entity                                        0
# Year                                          0
# Aquaculture production (metric tons)          0
# Capture fisheries production (metric tons)    0
# dtype: int64

# %%
df['new_Year'] = pd.to_datetime(df['Year'].astype(str), format='%Y')
df.set_index('new_Year', inplace=True)
df.drop(['Year'], axis=1 , inplace=True)
df.head()
# Out:
#                  Entity  Aquaculture production (metric tons)  \
# new_Year
# 1969-01-01  Afghanistan                                  60.0
# 1970-01-01  Afghanistan                                  60.0
# 1971-01-01  Afghanistan                                  60.0
# 1972-01-01  Afghanistan                                  60.0
# 1973-01-01  Afghanistan                                  60.0
#
#             Capture fisheries production (metric tons)
# new_Year
# 1969-01-01                                       400.0
# 1970-01-01                                       400.0
# 1971-01-01                                       500.0
# 1972-01-01                                       500.0
# 1973-01-01                                       500.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12727 entries, 1969-01-01 to 1969-01-01
# Data columns (total 3 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Entity                                      12727 non-null  object
#  1   Aquaculture production (metric tons)        12727 non-null  float64
#  2   Capture fisheries production (metric tons)  12727 non-null  float64
# dtypes: float64(2), object(1)
# memory usage: 397.7+ KB

# %%
new_df = df.sort_index()
new_df.head()
# Out:
#                               Entity  Aquaculture production (metric tons)  \
# new_Year
# 1960-01-01            Cayman Islands                                   0.0
# 1960-01-01                   Bahrain                                   0.0
# 1960-01-01               North Korea                                5236.0
# 1960-01-01  Northern Mariana Islands                                   0.0
# 1960-01-01                    Norway                                1900.0
#
#             Capture fisheries production (metric tons)
# new_Year
# 1960-01-01                                         0.0
# 1960-01-01                                      1500.0
# 1960-01-01                                    299190.0
# 1960-01-01                                       100.0
# 1960-01-01                                   1609362.0

# %%
new_df['Entity']= new_df['Entity'].astype('category')
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 12727 entries, 1960-01-01 to 2018-01-01
# Data columns (total 3 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Entity                                      12727 non-null  category
#  1   Aquaculture production (metric tons)        12727 non-null  float64
#  2   Capture fisheries production (metric tons)  12727 non-null  float64
# dtypes: category(1), float64(2)
# memory usage: 333.1 KB

# %%
new_df['Entity'].value_counts()
# Out:
# Afghanistan                   59
# Poland                        59
# Mozambique                    59
# Myanmar                       59
# Namibia                       59
#                               ..
# Serbia                        13
# Saint Martin (French part)    12
# Curacao                        8
# Sint Maarten (Dutch part)      8
# South Sudan                    7
# Name: Entity, Length: 231, dtype: int64

# %%
g = new_df.groupby(['new_Year'])
g.head()
# Out:
#                               Entity  Aquaculture production (metric tons)  \
# new_Year
# 1960-01-01            Cayman Islands                                   0.0
# 1960-01-01                   Bahrain                                   0.0
# 1960-01-01               North Korea                                5236.0
# 1960-01-01  Northern Mariana Islands                                   0.0
# 1960-01-01                    Norway                                1900.0
# ...                              ...                                   ...
# 2018-01-01                 Indonesia                            14772104.0
# 2018-01-01                Cape Verde                                   0.0
# 2018-01-01            Cayman Islands                                   0.0
# 2018-01-01  Central African Republic                                 190.0
# 2018-01-01               North Korea                              629060.0
#
#             Capture fisheries production (metric tons)
# ...

# %%
for key, group in g:
    print('+key: ', key)
    print('+number: ', len(group))
    print(group.head())
    print('\n')
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_12832\3824203819.py:1: FutureWarning: In a future version of pandas, a length 1 tuple will be returned when iterating over a groupby with a grouper equal to a list of length 1. Don't supply a list with a single grouper to avoid this warning.
#   for key, group in g:
# +key:  1960-01-01 00:00:00
# +number:  199
#                               Entity  Aquaculture production (metric tons)  \
# new_Year
# 1960-01-01            Cayman Islands                                   0.0
# 1960-01-01                   Bahrain                                   0.0
# 1960-01-01               North Korea                                5236.0
# 1960-01-01  Northern Mariana Islands                                   0.0
# 1960-01-01                    Norway                                1900.0
#
#             Capture fisheries production (metric tons)
# new_Year
# 1960-01-01                                         0.0
# ...

# %%
world_total = g.sum()
world_total.sum()
# Out:
# C:\Users\Acer\AppData\Local\Temp\ipykernel_12832\3635493060.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   world_total = g.sum()
# Aquaculture production (metric tons)          1.082617e+10
# Capture fisheries production (metric tons)    2.273393e+10
# dtype: float64

# %%
plt.style.use('ggplot')
world_total.plot(kind='area', alpha = 0.5, stacked = False , figsize = (20,10))
plt.legend()
plt.show()

# %%
country = new_df['Entity'].value_counts()
print(country)
print('Data type: ', type(country))
# Out:
# Afghanistan                   59
# Poland                        59
# Mozambique                    59
# Myanmar                       59
# Namibia                       59
#                               ..
# Serbia                        13
# Saint Martin (French part)    12
# Curacao                        8
# Sint Maarten (Dutch part)      8
# South Sudan                    7
# Name: Entity, Length: 231, dtype: int64
# Data type:  <class 'pandas.core.series.Series'>

# %%
'South Korea' in country
# Out:
# True

# %%
s = new_df.loc[new_df['Entity']=='South Korea']
c = new_df.loc[new_df['Entity']=='China']
a = new_df.loc[new_df['Entity']=='Afghanistan']

# %%
s_y = s[['Aquaculture production (metric tons)','Capture fisheries production (metric tons)']]
s_x = s.index

c_y = c[['Aquaculture production (metric tons)','Capture fisheries production (metric tons)']]
c_x = c.index

a_y = a[['Aquaculture production (metric tons)','Capture fisheries production (metric tons)']]
a_x = a.index

# %%
fig , axs = plt.subplots(1,3 , figsize=(15,5))
axs[0].plot(s_x, s_y)
axs[1].plot(c_x, c_y)
axs[2].plot(a_x, a_y)

# %% [markdown]
# ## Q2

# %%
# Access University of California, Irvine
import pandas as pd

# Read the CSV file into a DataFrame
df = pd.read_json("universities_ranking.json")
uci_ir = df[df['institution'].str.contains('University of California, Irvine')]
uci_ir.head()
# Out:
#       world_rank                       institution country  national_rank  \
# 46            47  University of California, Irvine     USA             35
# 164           65  University of California, Irvine     USA             43
# 279           80  University of California, Irvine     USA             50
# 1288          89  University of California, Irvine     USA             52
#
#       quality_of_education  alumni_employment  quality_of_faculty  \
# 46                     101                101                  38
# 164                    101                101                  39
# 279                    217                478                  42
# 1288                   227                567                  44
#
#       publications  influence  citations broad_impact  patents  score  year
# 46              59         57         52                    65  50.64  2012
# 164             69         67         61                   101  47.52  2013
# ...
